# %%
import pandas as pd

# Load dataset
df = pd.read_csv('feature_Engineered_train.csv')

# Count number of samples in each class
class_counts = df['label'].value_counts()

# Determine the smallest class size
min_class_size = class_counts.min()

# Downsample each class to the minimum size
downsampled_data = pd.DataFrame()
for class_label, group in df.groupby('label'):
    downsampled_group = group.sample(min_class_size, random_state=42)
    downsampled_data = downsampled_data.append(downsampled_group)

# Save downsampled data to file
downsampled_data.to_csv('feature_Engineered_train_downsampled.csv', index=False)
downsampled_data
# Out:
# /var/folders/g2/vk4vm02n3cng67bqls1m0knw0000gn/T/ipykernel_68360/2179948498.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   downsampled_data = downsampled_data.append(downsampled_group)
# /var/folders/g2/vk4vm02n3cng67bqls1m0knw0000gn/T/ipykernel_68360/2179948498.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   downsampled_data = downsampled_data.append(downsampled_group)
#        user_id  merchant_id  label  item_id  cat_id  seller_id  brand_id  \
# 4395     18306         3734      0   798188     177       3479      4415
# 13142    22914         2286      0   760357     389       4310      3320
# 17372    29826         4143      0  1010959     662       3213      2651
# 14655    25218         1500      0  1100608    1389       4976      6143
# 8096     18306         4733      0   926925    1505       3698      2104
# ...        ...          ...    ...      ...     ...        ...       ...
# 19457   231555           66      1   713695     883         66      2924
# 2102     18306         1710      1   427140     898       3716      7995
# 12210   347778         3323      1   825218     898       3323       683
# 22487   240003         2229      1   567794     664       2229      6332
# 2496     18306         1710      1   713720     407       1418      7141
#
#        time_stamp  action_type  age_range  ...  purchase_average_time  \
# 4395          702            0          3  ...               8.984848
# 13142        1111            0          4  ...              21.250000
# 17372        1008            0          4  ...              36.375000
# 14655         520            0          0  ...              16.500000
# 8096          704            0          3  ...               8.984848
# ...           ...          ...        ...  ...                    ...
# 19457        1108            0          8  ...              69.714286
# 2102         1102            0          3  ...               8.984848
# 12210        1110            0          3  ...              20.777778
# 22487        1111            0          3  ...             397.000000
# 2496          716            0          3  ...               8.984848
#
#        interaction_count  distinct_cat_per_user_merchant  \
# 4395                1444                             161
# 13142                250                              81
# 17372                510                              33
# 14655                566                              52
# 8096                1444                             161
# ...                  ...                             ...
# 19457                 90                              20
# 2102                1444                             161
# 12210                 62                              25
# 22487                 53                              25
# 2496                1444                             161
#
#        age_avg_per_merchant  distinct_brand_per_user_merchant  \
# 4395               2.976548                               319
# 13142              4.000000                                98
# 17372              4.000000                                49
# 14655              0.000000                                99
# 8096               3.000000                               319
# ...                     ...                               ...
# 19457              8.000000                                25
# 2102               3.000000                               319
# 12210              3.000000                                31
# 22487              3.000000                                17
# 2496               3.000000                               319
#
#        add_to_cart_to_click_ratio_per_merchant  avg_user_age_merchant  \
# 4395                                       0.0               2.976548
# 13142                                      0.0               4.000000
# 17372                                      0.0               4.000000
# 14655                                      0.0               0.000000
# 8096                                       0.0               3.000000
# ...                                        ...                    ...
# 19457                                      0.0               8.000000
# 2102                                       0.0               3.000000
# 12210                                      0.0               3.000000
# 22487                                      0.0               3.000000
# 2496                                       0.0               3.000000
#
#        purchase_frequency  Day  Month
# 4395             0.169668    2    7.0
# 13142            0.520000   11   11.0
# 17372            0.435294    8   10.0
# 14655            0.199647   20    5.0
# 8096             0.169668    4    7.0
# ...                   ...  ...    ...
# 19457            0.177778    8   11.0
# 2102             0.169668    2   11.0
# 12210            0.370968   10   11.0
# 22487            0.075472   11   11.0
# 2496             0.169668   16    7.0
#
# [8232 rows x 23 columns]
